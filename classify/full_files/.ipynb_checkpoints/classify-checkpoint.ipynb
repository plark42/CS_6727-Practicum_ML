# %%
import warnings
warnings.simplefilter(action='ignore', category=Warning)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier as Tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score, recall_score, precision_score
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder

# %%
def classify(model, X, y):
    #skf = StratifiedKFold()
    yp = cross_val_predict(model, X, y, cv=5)
    acc = accuracy_score(y,yp)*100
    pre = precision_score(y, yp)*100
    rec = recall_score(y,yp)*100
    return (acc, pre, rec)

# %%
def run(model, df):
    results = []
    for filetype in np.unique(df['filetype']):
        cond1 = df['filetype'] == filetype
        X = df[cond1].drop(['class', 'filetype', 'algorithm', 'filename'], axis=1)
        y = df[cond1]['class']
        acc, pre, rec = classify(model, X, y)
        print("%s: accuracy = %.2f, precision = %.2f, recall = %.2f" % (filetype, acc, pre, rec))
        results.append([filetype, acc, pre, rec])
    return results

# %%
def plot_results(results, model_name):
    results = pd.DataFrame(results, columns=['filetype', 'accuracy', 'precision', 'recall'])
    results.plot.bar(x='filetype')
    plt.legend(loc='lower right')
    plt.ylabel('percentage (%)')
    plt.title('classification results (%s)' % model_name);

# %%
df = pd.read_csv('features.csv')
pd.set_option('mode.use_inf_as_na', True)
df.fillna(0, inplace=True)
df['mime'] = LabelEncoder().fit_transform(df['mime'])

# %%
plot_results(run(Tree(), df), 'tree')
# Out:
# apk: accuracy = 100.00, precision = 100.00, recall = 100.00
# app: accuracy = 100.00, precision = 100.00, recall = 100.00
# doc: accuracy = 100.00, precision = 100.00, recall = 100.00
# elf: accuracy = 100.00, precision = 100.00, recall = 100.00
# exe: accuracy = 100.00, precision = 100.00, recall = 100.00
# gif: accuracy = 100.00, precision = 100.00, recall = 100.00
# html: accuracy = 100.00, precision = 100.00, recall = 100.00
# jpg: accuracy = 100.00, precision = 100.00, recall = 100.00
# mov: accuracy = 100.00, precision = 100.00, recall = 100.00
# mp3: accuracy = 100.00, precision = 100.00, recall = 100.00
# mp4: accuracy = 100.00, precision = 100.00, recall = 100.00
# obj: accuracy = 100.00, precision = 100.00, recall = 100.00
# pdf: accuracy = 95.12, precision = 100.00, recall = 90.25
# png: accuracy = 100.00, precision = 100.00, recall = 100.00
# ppt: accuracy = 100.00, precision = 100.00, recall = 100.00
# tgz: accuracy = 100.00, precision = 100.00, recall = 100.00
# txt: accuracy = 100.00, precision = 100.00, recall = 100.00
# wav: accuracy = 100.00, precision = 100.00, recall = 100.00
# xls: accuracy = 100.00, precision = 100.00, recall = 100.00
# zip: accuracy = 98.95, precision = 100.00, recall = 97.91

# %%
plot_results(run(RandomForestClassifier(), df), 'random forest')
# Out:
# apk: accuracy = 100.00, precision = 100.00, recall = 100.00
# app: accuracy = 100.00, precision = 100.00, recall = 100.00
# doc: accuracy = 100.00, precision = 100.00, recall = 100.00
# elf: accuracy = 100.00, precision = 100.00, recall = 100.00
# exe: accuracy = 100.00, precision = 100.00, recall = 100.00
# gif: accuracy = 100.00, precision = 100.00, recall = 100.00
# html: accuracy = 100.00, precision = 100.00, recall = 100.00
# jpg: accuracy = 100.00, precision = 100.00, recall = 100.00
# mov: accuracy = 100.00, precision = 100.00, recall = 100.00
# mp3: accuracy = 100.00, precision = 100.00, recall = 100.00
# mp4: accuracy = 100.00, precision = 100.00, recall = 100.00
# obj: accuracy = 100.00, precision = 100.00, recall = 100.00
# pdf: accuracy = 95.12, precision = 100.00, recall = 90.25
# png: accuracy = 100.00, precision = 100.00, recall = 100.00
# ppt: accuracy = 100.00, precision = 100.00, recall = 100.00
# tgz: accuracy = 100.00, precision = 100.00, recall = 100.00
# txt: accuracy = 100.00, precision = 100.00, recall = 100.00
# wav: accuracy = 100.00, precision = 100.00, recall = 100.00
# xls: accuracy = 100.00, precision = 100.00, recall = 100.00
# zip: accuracy = 98.95, precision = 100.00, recall = 97.91

# %%
plot_results(run(SVC(gamma='auto'), df), 'SVM')
# Out:
# apk: accuracy = 99.41, precision = 100.00, recall = 98.82
# app: accuracy = 98.46, precision = 100.00, recall = 96.91
# doc: accuracy = 99.96, precision = 100.00, recall = 99.91
# elf: accuracy = 100.00, precision = 100.00, recall = 100.00
# exe: accuracy = 97.85, precision = 100.00, recall = 95.69
# gif: accuracy = 98.98, precision = 100.00, recall = 97.97
# html: accuracy = 100.00, precision = 100.00, recall = 100.00
# jpg: accuracy = 97.82, precision = 100.00, recall = 95.63
# mov: accuracy = 99.26, precision = 100.00, recall = 98.52
# mp3: accuracy = 100.00, precision = 100.00, recall = 100.00
# mp4: accuracy = 99.37, precision = 100.00, recall = 98.73
# obj: accuracy = 100.00, precision = 100.00, recall = 100.00
# pdf: accuracy = 92.57, precision = 98.07, recall = 86.85
# png: accuracy = 98.74, precision = 100.00, recall = 97.48
# ppt: accuracy = 99.31, precision = 100.00, recall = 98.63
# tgz: accuracy = 97.62, precision = 99.93, recall = 95.30
# txt: accuracy = 97.44, precision = 100.00, recall = 94.88
# wav: accuracy = 100.00, precision = 100.00, recall = 100.00
# xls: accuracy = 100.00, precision = 100.00, recall = 100.00
# zip: accuracy = 98.26, precision = 100.00, recall = 96.52

# %%
plot_results(run(GaussianNB(), df), 'Bayes')
# Out:
# apk: accuracy = 67.51, precision = 60.64, recall = 99.78
# app: accuracy = 98.97, precision = 99.15, recall = 98.79
# doc: accuracy = 59.57, precision = 55.56, recall = 95.74
# elf: accuracy = 98.21, precision = 100.00, recall = 96.43
# exe: accuracy = 97.91, precision = 97.79, recall = 98.03
# gif: accuracy = 99.84, precision = 100.00, recall = 99.69
# html: accuracy = 90.00, precision = 100.00, recall = 80.00
# jpg: accuracy = 99.11, precision = 100.00, recall = 98.22
# mov: accuracy = 99.83, precision = 100.00, recall = 99.65
# mp3: accuracy = 92.60, precision = 94.94, recall = 90.00
# mp4: accuracy = 99.83, precision = 100.00, recall = 99.66
# obj: accuracy = 88.24, precision = 88.24, recall = 88.24
# pdf: accuracy = 73.78, precision = 65.77, recall = 99.20
# png: accuracy = 99.69, precision = 100.00, recall = 99.38
# ppt: accuracy = 62.29, precision = 57.03, recall = 99.74
# tgz: accuracy = 87.69, precision = 80.49, recall = 99.51
# txt: accuracy = 99.70, precision = 100.00, recall = 99.40
# wav: accuracy = 95.84, precision = 100.00, recall = 91.68
# xls: accuracy = 67.54, precision = 63.16, recall = 84.21
# zip: accuracy = 98.82, precision = 100.00, recall = 97.64

# %%
plot_results(run(KNeighborsClassifier(), df), 'KNN')
# Out:
# apk: accuracy = 99.91, precision = 100.00, recall = 99.82
# app: accuracy = 99.83, precision = 100.00, recall = 99.66
# doc: accuracy = 99.57, precision = 100.00, recall = 99.15
# elf: accuracy = 100.00, precision = 100.00, recall = 100.00
# exe: accuracy = 99.88, precision = 100.00, recall = 99.75
# gif: accuracy = 99.96, precision = 100.00, recall = 99.91
# html: accuracy = 93.00, precision = 100.00, recall = 86.00
# jpg: accuracy = 99.63, precision = 100.00, recall = 99.26
# mov: accuracy = 99.98, precision = 100.00, recall = 99.96
# mp3: accuracy = 100.00, precision = 100.00, recall = 100.00
# mp4: accuracy = 99.97, precision = 100.00, recall = 99.95
# obj: accuracy = 100.00, precision = 100.00, recall = 100.00
# pdf: accuracy = 93.86, precision = 100.00, recall = 87.73
# png: accuracy = 99.87, precision = 100.00, recall = 99.74
# ppt: accuracy = 99.74, precision = 100.00, recall = 99.49
# tgz: accuracy = 92.01, precision = 100.00, recall = 84.01
# txt: accuracy = 99.79, precision = 100.00, recall = 99.58
# wav: accuracy = 98.81, precision = 100.00, recall = 97.62
# xls: accuracy = 98.07, precision = 100.00, recall = 96.14
# zip: accuracy = 99.06, precision = 100.00, recall = 98.12

# %%
# copy the data
norm = df.copy()
  
# apply normalization techniques
for column in ['kurtosis','entropy','stdev','chi','autocorr','mean']:
    norm[column] = norm[column]  / norm[column].abs().max()
    
plot_results(run(MLPClassifier(), norm), 'MLP')
# Out:
# apk: accuracy = 99.91, precision = 99.95, recall = 99.88
# app: accuracy = 99.42, precision = 99.37, recall = 99.47
# doc: accuracy = 98.38, precision = 98.80, recall = 97.96
# elf: accuracy = 95.00, precision = 93.75, recall = 96.43
# exe: accuracy = 99.20, precision = 99.46, recall = 98.93
# gif: accuracy = 99.82, precision = 99.82, recall = 99.82
# html: accuracy = 64.00, precision = 62.96, recall = 68.00
# jpg: accuracy = 98.92, precision = 98.24, recall = 99.63
# mov: accuracy = 99.94, precision = 99.97, recall = 99.92
# mp3: accuracy = 94.40, precision = 93.70, recall = 95.20
# mp4: accuracy = 100.00, precision = 100.00, recall = 100.00
# obj: accuracy = 85.29, precision = 81.91, recall = 90.59
# pdf: accuracy = 85.39, precision = 83.01, recall = 89.00
# png: accuracy = 99.89, precision = 99.82, recall = 99.96
# ppt: accuracy = 99.90, precision = 100.00, recall = 99.80
# tgz: accuracy = 99.81, precision = 99.86, recall = 99.75
# txt: accuracy = 99.38, precision = 99.58, recall = 99.17
# wav: accuracy = 91.19, precision = 88.38, recall = 94.85
# xls: accuracy = 82.63, precision = 78.53, recall = 89.82
# zip: accuracy = 99.33, precision = 99.88, recall = 98.79

# %%
plot_results(run(LinearDiscriminantAnalysis(), df), 'LDA')
# Out:
# apk: accuracy = 88.79, precision = 92.44, recall = 84.48
# app: accuracy = 99.46, precision = 99.64, recall = 99.28
# doc: accuracy = 96.47, precision = 95.42, recall = 97.62
# elf: accuracy = 100.00, precision = 100.00, recall = 100.00
# exe: accuracy = 99.22, precision = 99.79, recall = 98.65
# gif: accuracy = 98.89, precision = 98.18, recall = 99.63
# html: accuracy = 100.00, precision = 100.00, recall = 100.00
# jpg: accuracy = 96.31, precision = 97.18, recall = 95.38
# mov: accuracy = 84.56, precision = 80.00, recall = 92.16
# mp3: accuracy = 99.90, precision = 100.00, recall = 99.80
# mp4: accuracy = 67.41, precision = 61.91, recall = 90.46
# obj: accuracy = 100.00, precision = 100.00, recall = 100.00
# pdf: accuracy = 90.72, precision = 86.76, recall = 96.10
# png: accuracy = 87.29, precision = 94.87, recall = 78.85
# ppt: accuracy = 91.92, precision = 98.81, recall = 84.86
# tgz: accuracy = 73.12, precision = 73.18, recall = 73.00
# txt: accuracy = 100.00, precision = 100.00, recall = 100.00
# wav: accuracy = 99.50, precision = 99.60, recall = 99.41
# xls: accuracy = 92.63, precision = 91.19, recall = 94.39
# zip: accuracy = 94.76, precision = 94.45, recall = 95.10

# %%
plot_results(run(QuadraticDiscriminantAnalysis(), df), 'QDA')
# Out:
# apk: accuracy = 50.00, precision = 0.00, recall = 0.00
# app: accuracy = 50.00, precision = 0.00, recall = 0.00
# doc: accuracy = 50.00, precision = 0.00, recall = 0.00
# elf: accuracy = 50.00, precision = 0.00, recall = 0.00
# exe: accuracy = 49.97, precision = 0.00, recall = 0.00
# gif: accuracy = 50.00, precision = 0.00, recall = 0.00
# html: accuracy = 50.00, precision = 0.00, recall = 0.00
# jpg: accuracy = 50.00, precision = 0.00, recall = 0.00
# mov: accuracy = 50.00, precision = 0.00, recall = 0.00
# mp3: accuracy = 90.00, precision = 83.33, recall = 100.00
# mp4: accuracy = 50.00, precision = 0.00, recall = 0.00
# obj: accuracy = 50.00, precision = 0.00, recall = 0.00
# pdf: accuracy = 50.00, precision = 0.00, recall = 0.00
# png: accuracy = 50.00, precision = 0.00, recall = 0.00
# ppt: accuracy = 50.00, precision = 0.00, recall = 0.00
# tgz: accuracy = 50.00, precision = 0.00, recall = 0.00
# txt: accuracy = 50.00, precision = 50.00, recall = 100.00
# wav: accuracy = 50.00, precision = 0.00, recall = 0.00
# xls: accuracy = 50.00, precision = 0.00, recall = 0.00
# zip: accuracy = 50.00, precision = 0.00, recall = 0.00

# %%
X = df.drop(['filename', 'class', 'algorithm', 'filetype'], axis=1)
y = df['class']
skf = StratifiedKFold()
yp = cross_val_predict(RandomForestClassifier(), X, y, cv=skf)
acc = accuracy_score(y,yp)*100
pre = precision_score(y, yp)*100
rec = recall_score(y,yp)*100
print(acc, pre, rec)
# Out:
# 99.96460789163581 100.0 99.92921663730766

# %%
results = []
for filetype in np.unique(df['filetype']):
    cond1 = df['filetype'] == filetype
    acc = accuracy_score(y[cond1],yp[cond1])*100
    pre = precision_score(y[cond1],yp[cond1])*100
    rec = recall_score(y[cond1],yp[cond1])*100
    print(filetype, acc, pre, rec)
    results.append([filetype, acc, pre, rec])
    
results = pd.DataFrame(results, columns=['filetype', 'accuracy', 'precision', 'recall'])
results.plot.bar(x='filetype')
plt.legend(loc='lower right')
plt.ylabel('percentage (%)')
plt.title('classification results (overall)');
# Out:
# apk 100.0 100.0 100.0
# app 100.0 100.0 100.0
# doc 100.0 100.0 100.0
# elf 100.0 100.0 100.0
# exe 100.0 100.0 100.0
# gif 100.0 100.0 100.0
# html 100.0 100.0 100.0
# jpg 100.0 100.0 100.0
# mov 100.0 100.0 100.0
# mp3 99.8 100.0 99.6
# mp4 100.0 100.0 100.0
# obj 100.0 100.0 100.0
# pdf 99.43426294820718 100.0 98.86852589641434
# png 100.0 100.0 100.0
# ppt 100.0 100.0 100.0
# tgz 100.0 100.0 100.0
# txt 100.0 100.0 100.0
# wav 99.9009900990099 100.0 99.8019801980198
# xls 100.0 100.0 100.0
# zip 99.9248523886205 100.0 99.84970477724102
