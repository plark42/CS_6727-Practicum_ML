# %%
import warnings
warnings.simplefilter(action='ignore', category=Warning)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier as Tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score, recall_score, precision_score
from sklearn.model_selection import StratifiedKFold

# %%
def classify(model, X, y):
    #skf = StratifiedKFold()
    yp = cross_val_predict(model, X, y, cv=5)
    acc = accuracy_score(y,yp)*100
    pre = precision_score(y, yp)*100
    rec = recall_score(y,yp)*100
    return (acc, pre, rec)

# %%
def run(model, df):
    results = []
    for filetype in np.unique(df['filetype']):
        cond1 = df['filetype'] == filetype
        X = df[cond1].drop(['class', 'filetype', 'algorithm'], axis=1)
        y = df[cond1]['class']
        acc, pre, rec = classify(model, X, y)
        print("%s: accuracy = %.2f, precision = %.2f, recall = %.2f" % (filetype, acc, pre, rec))
        results.append([filetype, acc, pre, rec])
    return results

# %%
def plot_results(results, model_name):
    results = pd.DataFrame(results, columns=['filetype', 'accuracy', 'precision', 'recall'])
    results.plot.bar(x='filetype')
    plt.legend(loc='lower right')
    plt.ylabel('percentage (%)')
    plt.title('classification results (%s)' % model_name);

# %%
df = pd.read_csv('features.csv')
pd.set_option('mode.use_inf_as_na', True)
df.fillna(0, inplace=True)

# %%
plot_results(run(Tree(), df), 'tree')
# Out:
# apk: accuracy = 98.13, precision = 100.00, recall = 96.26
# app: accuracy = 100.00, precision = 100.00, recall = 100.00
# doc: accuracy = 99.57, precision = 100.00, recall = 99.15
# elf: accuracy = 100.00, precision = 100.00, recall = 100.00
# exe: accuracy = 100.00, precision = 100.00, recall = 100.00
# gif: accuracy = 99.97, precision = 100.00, recall = 99.93
# html: accuracy = 100.00, precision = 100.00, recall = 100.00
# jpg: accuracy = 99.91, precision = 100.00, recall = 99.82
# mov: accuracy = 96.47, precision = 100.00, recall = 92.94
# mp3: accuracy = 99.80, precision = 100.00, recall = 99.60
# mp4: accuracy = 96.04, precision = 100.00, recall = 92.07
# obj: accuracy = 100.00, precision = 100.00, recall = 100.00
# pdf: accuracy = 97.73, precision = 100.00, recall = 95.46
# png: accuracy = 97.66, precision = 100.00, recall = 95.32
# ppt: accuracy = 99.96, precision = 100.00, recall = 99.92
# tgz: accuracy = 95.86, precision = 100.00, recall = 91.71
# txt: accuracy = 100.00, precision = 100.00, recall = 100.00
# wav: accuracy = 100.00, precision = 100.00, recall = 100.00
# xls: accuracy = 98.77, precision = 100.00, recall = 97.54
# zip: accuracy = 95.91, precision = 100.00, recall = 91.81

# %%
plot_results(run(RandomForestClassifier(), df), 'random forest')
# Out:
# apk: accuracy = 99.52, precision = 100.00, recall = 99.04
# app: accuracy = 100.00, precision = 100.00, recall = 100.00
# doc: accuracy = 99.79, precision = 100.00, recall = 99.57
# elf: accuracy = 100.00, precision = 100.00, recall = 100.00
# exe: accuracy = 100.00, precision = 100.00, recall = 100.00
# gif: accuracy = 99.97, precision = 100.00, recall = 99.93
# html: accuracy = 100.00, precision = 100.00, recall = 100.00
# jpg: accuracy = 99.91, precision = 100.00, recall = 99.82
# mov: accuracy = 98.43, precision = 100.00, recall = 96.86
# mp3: accuracy = 99.90, precision = 100.00, recall = 99.80
# mp4: accuracy = 99.68, precision = 100.00, recall = 99.36
# obj: accuracy = 100.00, precision = 100.00, recall = 100.00
# pdf: accuracy = 99.79, precision = 100.00, recall = 99.59
# png: accuracy = 98.54, precision = 100.00, recall = 97.08
# ppt: accuracy = 99.95, precision = 100.00, recall = 99.90
# tgz: accuracy = 97.53, precision = 100.00, recall = 95.05
# txt: accuracy = 100.00, precision = 100.00, recall = 100.00
# wav: accuracy = 100.00, precision = 100.00, recall = 100.00
# xls: accuracy = 99.47, precision = 100.00, recall = 98.95
# zip: accuracy = 97.69, precision = 100.00, recall = 95.38

# %%
plot_results(run(SVC(gamma='auto'), df), 'SVM')
# Out:
# apk: accuracy = 95.26, precision = 94.70, recall = 95.90
# app: accuracy = 100.00, precision = 100.00, recall = 100.00
# doc: accuracy = 99.74, precision = 99.66, recall = 99.83
# elf: accuracy = 100.00, precision = 100.00, recall = 100.00
# exe: accuracy = 100.00, precision = 100.00, recall = 100.00
# gif: accuracy = 98.87, precision = 100.00, recall = 97.75
# html: accuracy = 100.00, precision = 100.00, recall = 100.00
# jpg: accuracy = 98.86, precision = 100.00, recall = 97.72
# mov: accuracy = 88.41, precision = 87.99, recall = 88.96
# mp3: accuracy = 100.00, precision = 100.00, recall = 100.00
# mp4: accuracy = 88.13, precision = 83.61, recall = 94.86
# obj: accuracy = 100.00, precision = 100.00, recall = 100.00
# pdf: accuracy = 93.28, precision = 91.82, recall = 95.03
# png: accuracy = 94.27, precision = 96.89, recall = 91.47
# ppt: accuracy = 99.01, precision = 100.00, recall = 98.02
# tgz: accuracy = 90.33, precision = 91.30, recall = 89.15
# txt: accuracy = 97.59, precision = 100.00, recall = 95.18
# wav: accuracy = 100.00, precision = 100.00, recall = 100.00
# xls: accuracy = 100.00, precision = 100.00, recall = 100.00
# zip: accuracy = 94.62, precision = 96.67, recall = 92.44

# %%
plot_results(run(GaussianNB(), df), 'Bayes')
# Out:
# apk: accuracy = 68.45, precision = 61.34, recall = 99.79
# app: accuracy = 98.87, precision = 98.51, recall = 99.25
# doc: accuracy = 57.87, precision = 54.48, recall = 95.74
# elf: accuracy = 98.21, precision = 100.00, recall = 96.43
# exe: accuracy = 99.40, precision = 100.00, recall = 98.81
# gif: accuracy = 89.60, precision = 82.93, recall = 99.73
# html: accuracy = 90.00, precision = 100.00, recall = 80.00
# jpg: accuracy = 55.48, precision = 52.99, recall = 96.92
# mov: accuracy = 62.20, precision = 56.96, recall = 99.83
# mp3: accuracy = 57.50, precision = 54.55, recall = 90.00
# mp4: accuracy = 76.87, precision = 68.38, recall = 99.96
# obj: accuracy = 88.24, precision = 88.24, recall = 88.24
# pdf: accuracy = 73.63, precision = 65.63, recall = 99.20
# png: accuracy = 54.75, precision = 52.52, recall = 99.01
# ppt: accuracy = 76.28, precision = 67.84, recall = 99.93
# tgz: accuracy = 77.57, precision = 70.81, recall = 93.78
# txt: accuracy = 99.40, precision = 99.70, recall = 99.11
# wav: accuracy = 92.12, precision = 87.75, recall = 97.92
# xls: accuracy = 67.54, precision = 63.16, recall = 84.21
# zip: accuracy = 70.91, precision = 63.27, recall = 99.69

# %%
plot_results(run(KNeighborsClassifier(), df), 'KNN')
# Out:
# apk: accuracy = 96.06, precision = 100.00, recall = 92.12
# app: accuracy = 100.00, precision = 100.00, recall = 100.00
# doc: accuracy = 99.36, precision = 100.00, recall = 98.72
# elf: accuracy = 100.00, precision = 100.00, recall = 100.00
# exe: accuracy = 100.00, precision = 100.00, recall = 100.00
# gif: accuracy = 99.88, precision = 100.00, recall = 99.76
# html: accuracy = 93.00, precision = 100.00, recall = 86.00
# jpg: accuracy = 99.60, precision = 100.00, recall = 99.20
# mov: accuracy = 89.90, precision = 100.00, recall = 79.81
# mp3: accuracy = 100.00, precision = 100.00, recall = 100.00
# mp4: accuracy = 90.80, precision = 100.00, recall = 81.60
# obj: accuracy = 100.00, precision = 100.00, recall = 100.00
# pdf: accuracy = 94.40, precision = 100.00, recall = 88.80
# png: accuracy = 94.85, precision = 100.00, recall = 89.70
# ppt: accuracy = 99.97, precision = 100.00, recall = 99.94
# tgz: accuracy = 90.60, precision = 100.00, recall = 81.21
# txt: accuracy = 99.79, precision = 100.00, recall = 99.58
# wav: accuracy = 99.75, precision = 100.00, recall = 99.50
# xls: accuracy = 97.89, precision = 100.00, recall = 95.79
# zip: accuracy = 92.03, precision = 100.00, recall = 84.06

# %%
# copy the data
norm = df.copy()
  
# apply normalization techniques
for column in ['kurtosis','entropy','stdev','chi','autocorr','mean']:
    norm[column] = norm[column]  / norm[column].abs().max()
    
plot_results(run(MLPClassifier(), norm), 'MLP')
# Out:
# apk: accuracy = 90.44, precision = 85.27, recall = 97.77
# app: accuracy = 97.37, precision = 95.65, recall = 99.25
# doc: accuracy = 76.89, precision = 77.34, recall = 76.09
# elf: accuracy = 94.29, precision = 92.47, recall = 96.43
# exe: accuracy = 97.62, precision = 96.51, recall = 98.81
# gif: accuracy = 97.33, precision = 95.92, recall = 98.87
# html: accuracy = 75.00, precision = 75.51, recall = 74.00
# jpg: accuracy = 79.82, precision = 73.39, recall = 93.54
# mov: accuracy = 77.22, precision = 69.69, recall = 96.34
# mp3: accuracy = 81.40, precision = 79.18, recall = 85.20
# mp4: accuracy = 76.72, precision = 77.75, recall = 74.88
# obj: accuracy = 81.76, precision = 89.71, recall = 71.76
# pdf: accuracy = 81.84, precision = 83.50, recall = 79.36
# png: accuracy = 74.93, precision = 80.79, recall = 65.42
# ppt: accuracy = 95.15, precision = 96.79, recall = 93.38
# tgz: accuracy = 68.94, precision = 69.27, recall = 68.11
# txt: accuracy = 99.32, precision = 99.82, recall = 98.81
# wav: accuracy = 98.08, precision = 97.61, recall = 98.58
# xls: accuracy = 65.61, precision = 62.90, recall = 76.14
# zip: accuracy = 66.78, precision = 63.93, recall = 77.00

# %%
plot_results(run(LinearDiscriminantAnalysis(), df), 'LDA')
# Out:
# apk: accuracy = 89.09, precision = 93.33, recall = 84.20
# app: accuracy = 99.62, precision = 100.00, recall = 99.25
# doc: accuracy = 96.47, precision = 95.42, recall = 97.62
# elf: accuracy = 100.00, precision = 100.00, recall = 100.00
# exe: accuracy = 100.00, precision = 100.00, recall = 100.00
# gif: accuracy = 98.13, precision = 96.91, recall = 99.44
# html: accuracy = 100.00, precision = 100.00, recall = 100.00
# jpg: accuracy = 96.31, precision = 97.18, recall = 95.38
# mov: accuracy = 82.00, precision = 79.84, recall = 85.62
# mp3: accuracy = 98.20, precision = 97.07, recall = 99.40
# mp4: accuracy = 84.81, precision = 77.17, recall = 98.88
# obj: accuracy = 100.00, precision = 100.00, recall = 100.00
# pdf: accuracy = 89.35, precision = 85.96, recall = 94.06
# png: accuracy = 87.29, precision = 94.87, recall = 78.85
# ppt: accuracy = 94.55, precision = 100.00, recall = 89.10
# tgz: accuracy = 83.60, precision = 83.47, recall = 83.80
# txt: accuracy = 99.85, precision = 100.00, recall = 99.70
# wav: accuracy = 98.92, precision = 98.35, recall = 99.50
# xls: accuracy = 92.63, precision = 91.19, recall = 94.39
# zip: accuracy = 85.19, precision = 82.28, recall = 89.69

# %%
plot_results(run(QuadraticDiscriminantAnalysis(), df), 'QDA')
# Out:
# apk: accuracy = 90.69, precision = 84.48, recall = 99.69
# app: accuracy = 99.40, precision = 98.81, recall = 100.00
# doc: accuracy = 96.04, precision = 96.00, recall = 96.09
# elf: accuracy = 50.00, precision = 0.00, recall = 0.00
# exe: accuracy = 100.00, precision = 100.00, recall = 100.00
# gif: accuracy = 99.72, precision = 99.66, recall = 99.77
# html: accuracy = 50.00, precision = 0.00, recall = 0.00
# jpg: accuracy = 98.34, precision = 99.06, recall = 97.60
# mov: accuracy = 70.09, precision = 62.61, recall = 99.75
# mp3: accuracy = 97.70, precision = 98.38, recall = 97.00
# mp4: accuracy = 84.44, precision = 76.43, recall = 99.61
# obj: accuracy = 50.00, precision = 0.00, recall = 0.00
# pdf: accuracy = 88.88, precision = 82.25, recall = 99.16
# png: accuracy = 70.32, precision = 62.89, recall = 99.15
# ppt: accuracy = 99.48, precision = 99.12, recall = 99.85
# tgz: accuracy = 78.82, precision = 70.94, recall = 97.65
# txt: accuracy = 50.00, precision = 0.00, recall = 0.00
# wav: accuracy = 99.92, precision = 100.00, recall = 99.83
# xls: accuracy = 95.09, precision = 97.77, recall = 92.28
# zip: accuracy = 78.47, precision = 70.38, recall = 98.31

# %%
X = df.drop(['class', 'algorithm', 'filetype'], axis=1)
y = df['class']
skf = StratifiedKFold()
yp = cross_val_predict(RandomForestClassifier(), X, y, cv=skf)
acc = accuracy_score(y,yp)*100
pre = precision_score(y, yp)*100
rec = recall_score(y,yp)*100
print(acc, pre, rec)
# Out:
# 99.33411471687056 100.0 98.66822943374112

# %%
results = []
for filetype in np.unique(df['filetype']):
    cond1 = df['filetype'] == filetype
    acc = accuracy_score(y[cond1],yp[cond1])*100
    pre = precision_score(y[cond1],yp[cond1])*100
    rec = recall_score(y[cond1],yp[cond1])*100
    print(filetype, acc, pre, rec)
    results.append([filetype, acc, pre, rec])
    
results = pd.DataFrame(results, columns=['filetype', 'accuracy', 'precision', 'recall'])
results.plot.bar(x='filetype')
plt.legend(loc='lower right')
plt.ylabel('percentage (%)')
plt.title('classification results (overall)');
# Out:
# apk 99.21293042867183 100.0 98.42586085734364
# app 99.3984962406015 100.0 98.796992481203
# doc 99.14893617021276 100.0 98.29787234042553
# elf 96.78571428571429 100.0 93.57142857142857
# exe 99.28571428571429 100.0 98.57142857142858
# gif 99.35549525101763 100.0 98.71099050203527
# html 100.0 100.0 100.0
# jpg 99.32307692307693 100.0 98.64615384615385
# mov 99.34857142857143 100.0 98.69714285714286
# mp3 99.5 100.0 99.0
# mp4 99.46280991735537 100.0 98.92561983471074
# obj 99.41176470588235 100.0 98.82352941176471
# pdf 99.1792828685259 100.0 98.35856573705179
# png 99.29563492063492 100.0 98.59126984126985
# ppt 99.45908460471567 100.0 98.91816920943135
# tgz 99.34607645875252 100.0 98.69215291750503
# txt 99.375 100.0 98.75
# wav 99.0 100.0 98.0
# xls 98.42105263157895 100.0 96.84210526315789
# zip 99.5 100.0 99.0
